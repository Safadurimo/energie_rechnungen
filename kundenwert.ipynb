# %%
import pandas as pd

# %%
import os

file_name = "temperaturdaten\\tageswerte_KL_00691_akt\\produkt_klima_tag_20230410_20241010_00691.txt"
file_path = os.path.join(os.getcwd(), file_name)

daten = pd.read_csv(file_path, sep=";", usecols=[1, 13])

#filtered_data = daten[daten['TMK'] > 25]
#print(filtered_data)
daten
# Out:
#      MESS_DATUM   TMK
# 0      20230410  11.6
# 1      20230411   7.4
# 2      20230412   6.8
# 3      20230413   7.1
# 4      20230414   8.5
# ..          ...   ...
# 545    20241006   9.3
# 546    20241007  12.7
# 547    20241008  15.3
# 548    20241009  14.2
# 549    20241010  11.4
#
# [550 rows x 2 columns]

# %%
daten.columns
import matplotlib.pyplot as plt

daten.plot(x='MESS_DATUM', y=' TMK')
plt.xlabel('Datum')
plt.ylabel('Tagesmitteltemperaturen')
plt.title('Temperature Data')
plt.show()
